# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from subprocess import PIPE, run
import pandas as pd

R = run(args=["GBM01.exe", ".1", ".1"], stdout=PIPE)
D = pd.read_csv("singlePath.csv")

plt.figure()
plt.plot(D['1'])
plt.show()

# %%
D
# Out:
#             1
# 0    0.992276
# 1    1.001070
# 2    0.991803
# 3    0.993582
# 4    0.976926
# 5    0.989378
# 6    1.001660
# 7    1.000640
# 8    1.022910
# 9    1.021990
# 10   1.019470
# 11   1.033450
# 12   1.028500
# 13   1.005100
# 14   0.996900
# 15   0.971589
# 16   0.938555
# 17   0.936062
# 18   0.945177
# 19   0.945328
# 20   0.928977
# 21   0.935297
# 22   0.915557
# 23   0.921370
# 24   0.928094
# 25   0.944446
# 26   0.953286
# 27   0.950464
# 28   0.930441
# 29   0.922930
# ..        ...
# 970  1.592840
# 971  1.581200
# 972  1.548260
# 973  1.529480
# 974  1.501160
# 975  1.523050
# 976  1.527740
# 977  1.582530
# 978  1.557390
# 979  1.541400
# 980  1.561610
# 981  1.591540
# 982  1.589490
# 983  1.599200
# 984  1.564630
# 985  1.531790
# 986  1.535060
# 987  1.557280
# 988  1.569740
# 989  1.531280
# 990  1.565410
# 991  1.605850
# 992  1.613580
# 993  1.622780
# 994  1.638260
# 995  1.635210
# 996  1.652950
# 997  1.677040
# 998  1.669960
# 999  1.630310
#
# ...

# %%
D.mean()
# Out:
# 1    1.048845
# dtype: float64

# %%
R = run(args=["monteCarloGBM.exe", ".1", ".1"], stdout=PIPE)
df = pd.read_csv("multiRuns.csv", header=None)

plt.figure()
for i in range(100):
    plt.plot(df[i])
plt.show()

# %%
df[0][999]
# Out:
# 2.1793499999999999
