# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from subprocess import PIPE, run
import pandas as pd

R = run(args=["GBM01.exe"], stdout=PIPE)
print(R.returncode)
print(R.stdout.decode("UTF-08"))
D = pd.read_csv("singlePath.csv")

plt.figure()
plt.plot(D['1'])
plt.show()
# Out:
# 0
